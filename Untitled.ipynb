# %% [markdown]
# ### Similarity function

# %%
import pandas as pd
from scipy import spatial

# %%
cbb21 = pd.read_csv('cbb_21.csv', index_col = 0)
s16_team_avg = pd.read_csv('avg_by_round.csv', index_col = 0)
s16_teams = pd.read_csv('cbb_s16.csv', index_col = 0)

# %%
# checking the teams most correlated similarity to a seed

def full_similarity(df1, df2):
    final_results = []
    for x in df1.TEAM:
        max_similarity = 0
        current = []
        
        for y in df2.POSTSEASON:
        
            similarity = 1/(spatial.distance.euclidean(df1[df1.TEAM == x].drop(columns = ['TEAM', 'SEED', 'BARTHAG']), 
                                         df2[df2.POSTSEASON == y].drop(columns = ['POSTSEASON', 'BARTHAG'])))
            if similarity > max_similarity:
                max_similarity = similarity
                current_team = x
                current_postseason_rank = y
        current.append(current_team)
        current.append(max_similarity)
        current.append(current_postseason_rank)
        final_results.append(current)
    
    return final_results

# %%
full_similarity(cbb21, s16_team_avg)
# Out:
# [['Michigan', 0.09031491219149301, 6],
#  ['Baylor', 0.0727941822884859, 7],
#  ['Illinois', 0.10660715732047107, 6],
#  ['Gonzaga', 0.05831543648032874, 7],
#  ['Iowa', 0.0833080708269862, 6],
#  ['Ohio St.', 0.10496464025243253, 4],
#  ['Houston', 0.06337739243271463, 5],
#  ['Alabama', 0.07614132242932345, 5],
#  ['West Virginia', 0.0884848035290048, 3],
#  ['Texas', 0.15277892783959926, 2],
#  ['Kansas', 0.08087182788724902, 2],
#  ['Arkansas', 0.09922184699953115, 3],
#  ['Florida St.', 0.10764583971965705, 3],
#  ['Virginia', 0.04652369674397319, 6],
#  ['Purdue', 0.10607194879859064, 3],
#  ['Oklahoma St.', 0.11344529056573163, 2],
#  ['Villanova', 0.06910811526338799, 3],
#  ['Tennessee', 0.10590113075385031, 2],
#  ['Creighton', 0.06521097957973603, 6],
#  ['Colorado', 0.1097611774697861, 3],
#  ['Texas Tech', 0.11431330623466418, 2],
#  ['BYU', 0.07773614520535936, 3],
#  ['USC', 0.09960784505146761, 3],
#  ['San Diego St.', 0.1126316917437217, 2],
#  ['Florida', 0.13552170494783541, 2],
#  ['Connecticut', 0.09351031485843193, 2],
#  ['Clemson', 0.056788544814260516, 2],
#  ['Oregon', 0.07071970470295581, 3],
#  ['Oklahoma', 0.06658106333294711, 2],
#  ['North Carolina', 0.06572143916953627, 3],
#  ['LSU', 0.08387784642287621, 3],
#  ['Loyola Chicago', 0.050619713972186633, 6],
#  ['St. Bonaventure', 0.0850673846404796, 2],
#  ['Missouri', 0.13541515888851355, 2],
#  ['Wisconsin', 0.05923099021723612, 2],
#  ['Georgia Tech', 0.06672764840889205, 2],
#  ['Rutgers', 0.07456463743338704, 2],
#  ['Virginia Tech', 0.11257865824133896, 2],
#  ['Maryland', 0.061986721050885304, 2],
#  ['VCU', 0.07366794648116912, 2],
#  ['Michigan St.', 0.08162328851044043, 1],
#  ['Wichita St.', 0.09452316119245437, 1],
#  ['Syracuse', 0.06918817649812815, 2],
#  ['UCLA', 0.09147103329172163, 2],
#  ['Utah St.', 0.05669672399941449, 2],
#  ['Drake', 0.06376570156193435, 2],
#  ['Georgetown', 0.06987077841363869, 1],
#  ['Oregon St.', 0.09827307805592489, 1],
#  ['UC Santa Barbara', 0.10443082815597901, 1],
#  ['Winthrop', 0.07801166466183117, 1],
#  ['Ohio', 0.07277461874938962, 1],
#  ['North Texas', 0.06663760272245015, 1],
#  ['UNC Greensboro', 0.056297888159034366, 1],
#  ['Liberty', 0.05053626992516646, 1],
#  ['Colgate', 0.055199671752818744, 2],
#  ['Eastern Washington', 0.06747574150736653, 1],
#  ['Abilene Christian', 0.06326162288463426, 1],
#  ['Morehead St.', 0.060349207974982055, 1],
#  ['Iona', 0.06059576075977355, 1],
#  ['Oral Roberts', 0.056394914672211874, 1],
#  ['Grand Canyon', 0.06980519313560804, 1],
#  ['Cleveland St.', 0.07425645277444023, 1],
#  ['Drexel', 0.06156414719288952, 1],
#  ["Mount St. Mary's", 0.04609990271373796, 1],
#  ['Hartford', 0.049819808724592234, 1],
#  ['Norfolk St.', 0.06483828134587126, 1],
#  ['Texas Southern', 0.05798594768950962, 1],
#  ['Appalachian St.', 0.051599173877055184, 1]]

# %%
Teams_by_avg_postseason = pd.DataFrame(full_similarity(cbb21, s16_team_avg), 
                            columns = ['Team', 'Similarity_Score', 'Postseason_Finish'])

# %%
# checking each teams similarity to all the different seeds

def full_similarity2(df1, df2):
    final_results = []
    
    for x in df1.TEAM:
        max_similarity = 0
        
        for y in df2.POSTSEASON:
            similarity = 1/(spatial.distance.euclidean(df1[df1.TEAM == x].drop(columns = ['TEAM', 'SEED', 'BARTHAG']), 
                                         df2[df2.POSTSEASON == y].drop(columns = ['POSTSEASON', 'BARTHAG'])))
            if similarity > max_similarity:
                max_similarity = similarity
                current_team = x
                current_postseason_rank = y
            final_results.append(x + ', ' + str(similarity) + ', ' + str(y))
    
    return final_results

# %%
full_similarity2(cbb21, s16_team_avg)
# Out:
# ['Michigan, 0.043987484580258196, 1',
#  'Michigan, 0.05588801284388184, 2',
#  'Michigan, 0.0650472042346112, 3',
#  'Michigan, 0.0668874333163471, 4',
#  'Michigan, 0.0676875393641978, 5',
#  'Michigan, 0.08283378607558742, 6',
#  'Michigan, 0.07478729356911597, 7',
#  'Baylor, 0.04038615747763096, 1',
#  'Baylor, 0.050156915661401784, 2',
#  'Baylor, 0.056605274629342596, 3',
#  'Baylor, 0.05921019611120142, 4',
#  'Baylor, 0.058840887942623946, 5',
#  'Baylor, 0.058008958580333725, 6',
#  'Baylor, 0.06785475116317397, 7',
#  'Illinois, 0.0493788669658046, 1',
#  'Illinois, 0.06642409318252683, 2',
#  'Illinois, 0.08033919559193115, 3',
#  'Illinois, 0.09451904535316781, 4',
#  'Illinois, 0.07801930406142199, 5',
#  'Illinois, 0.09633694903854474, 6',
#  'Illinois, 0.08483159867654012, 7',
#  'Gonzaga, 0.03292199572600831, 1',
#  'Gonzaga, 0.03905154987971082, 2',
#  'Gonzaga, 0.043806926001190065, 3',
#  'Gonzaga, 0.04927416996966458, 4',
#  'Gonzaga, 0.04387341645254749, 5',
#  'Gonzaga, 0.05394916269067185, 6',
#  'Gonzaga, 0.055102131623696364, 7',
#  'Iowa, 0.04333957072980866, 1',
#  'Iowa, 0.053317214882336414, 2',
#  'Iowa, 0.0631232876715632, 3',
#  'Iowa, 0.06586420563240075, 4',
#  'Iowa, 0.06166070287158132, 5',
#  'Iowa, 0.07690155097191298, 6',
#  'Iowa, 0.07298983274012173, 7',
#  'Ohio St., 0.0581543637981992, 1',
#  'Ohio St., 0.07748000207258599, 2',
#  'Ohio St., 0.08885517654566115, 3',
#  'Ohio St., 0.094993664438396, 4',
#  'Ohio St., 0.07923714193640291, 5',
#  'Ohio St., 0.087639007631663, 6',
#  'Ohio St., 0.07708861061295999, 7',
#  'Houston, 0.04289920933572883, 1',
#  'Houston, 0.05404040345983469, 2',
#  'Houston, 0.05571295333765939, 3',
#  'Houston, 0.05623381977278872, 4',
#  'Houston, 0.059600093893029456, 5',
#  'Houston, 0.053248903737419334, 6',
#  'Houston, 0.054499969829426884, 7',
#  'Alabama, 0.05186166533361832, 1',
#  'Alabama, 0.06534217242275399, 2',
#  'Alabama, 0.06676609726293442, 3',
#  'Alabama, 0.06164078433114787, 4',
#  'Alabama, 0.07075401793645379, 5',
#  'Alabama, 0.05775825855194548, 6',
#  'Alabama, 0.05820588784247053, 7',
#  'West Virginia, 0.06677134496704626, 1',
#  'West Virginia, 0.07815193660829335, 2',
#  'West Virginia, 0.08129172152162889, 3',
#  'West Virginia, 0.07044042902098917, 4',
#  'West Virginia, 0.07298590586910583, 5',
#  'West Virginia, 0.06002052225487397, 6',
#  'West Virginia, 0.05756391000122276, 7',
#  'Texas, 0.08393004766678881, 1',
#  'Texas, 0.1325309859071759, 2',
#  'Texas, 0.1204506738861079, 3',
#  'Texas, 0.0994922538339304, 4',
#  'Texas, 0.10377898743578172, 5',
#  'Texas, 0.07701830526057538, 6',
#  'Texas, 0.06966464240756184, 7',
#  'Kansas, 0.06259246342361527, 1',
#  'Kansas, 0.07482092307404015, 2',
#  'Kansas, 0.07423403592379821, 3',
#  'Kansas, 0.06289301573160912, 4',
#  'Kansas, 0.07182191096830944, 5',
#  'Kansas, 0.06141655081677459, 6',
#  'Kansas, 0.05567439804088655, 7',
#  'Arkansas, 0.06959318396792112, 1',
#  'Arkansas, 0.08947762143573373, 2',
#  'Arkansas, 0.09026553399604464, 3',
#  'Arkansas, 0.07612254758602131, 4',
#  'Arkansas, 0.08059237114077736, 5',
#  'Arkansas, 0.06952114298795103, 6',
#  'Arkansas, 0.06257275401734128, 7',
#  'Florida St., 0.06423647031545202, 1',
#  'Florida St., 0.0898030082964964, 2',
#  'Florida St., 0.09718434887716636, 3',
#  'Florida St., 0.0906693142198686, 4',
#  'Florida St., 0.09557224897815698, 5',
#  'Florida St., 0.07234214299066598, 6',
#  'Florida St., 0.07354855348860809, 7',
#  'Virginia, 0.0380331761023226, 1',
#  'Virginia, 0.04150998971398504, 2',
#  'Virginia, 0.04270320838990478, 3',
#  'Virginia, 0.04132763282741768, 4',
#  'Virginia, 0.042221756676227545, 5',
#  'Virginia, 0.044455464208523296, 6',
#  'Virginia, 0.04203005524836047, 7',
#  'Purdue, 0.0732800892762613, 1',
#  'Purdue, 0.0952714407989676, 2',
#  'Purdue, 0.09589968257833988, 3',
#  'Purdue, 0.07899489398663785, 4',
#  'Purdue, 0.08224647111992411, 5',
#  'Purdue, 0.07352201324250991, 6',
#  'Purdue, 0.0639161216480974, 7',
#  'Oklahoma St., 0.08175546159010798, 1',
#  'Oklahoma St., 0.10188672180569473, 2',
#  'Oklahoma St., 0.09492867232872589, 3',
#  'Oklahoma St., 0.07959147654240088, 4',
#  'Oklahoma St., 0.08572548839005391, 5',
#  'Oklahoma St., 0.06528191793534333, 6',
#  'Oklahoma St., 0.06002275224626237, 7',
#  'Villanova, 0.0527701322380537, 1',
#  'Villanova, 0.060659514310279695, 2',
#  'Villanova, 0.06464090420486833, 3',
#  'Villanova, 0.06027175310195668, 4',
#  'Villanova, 0.05837985562995371, 5',
#  'Villanova, 0.0629403252138477, 6',
#  'Villanova, 0.0573794826486256, 7',
#  'Tennessee, 0.07550047155741219, 1',
#  'Tennessee, 0.09576003478869904, 2',
#  'Tennessee, 0.08607163174843696, 3',
#  'Tennessee, 0.07150583364028365, 4',
#  'Tennessee, 0.08530444821660602, 5',
#  'Tennessee, 0.0632538329593937, 6',
#  'Tennessee, 0.05774972599976785, 7',
#  'Creighton, 0.050433962086736124, 1',
#  'Creighton, 0.058390393303206965, 2',
#  'Creighton, 0.06113467971626487, 3',
#  'Creighton, 0.05840837775254771, 4',
#  'Creighton, 0.05953732045355975, 5',
#  'Creighton, 0.061218839112477136, 6',
#  'Creighton, 0.0571142445485713, 7',
#  'Colorado, 0.07021558289646983, 1',
#  'Colorado, 0.0930675814548277, 2',
#  'Colorado, 0.09890522366265998, 3',
#  'Colorado, 0.07995200543647923, 4',
#  'Colorado, 0.08975981960028839, 5',
#  'Colorado, 0.07877949886947826, 6',
#  'Colorado, 0.0694988607161851, 7',
#  'Texas Tech, 0.08375374395612548, 1',
#  'Texas Tech, 0.10258632432644652, 2',
#  'Texas Tech, 0.08687510320344993, 3',
#  'Texas Tech, 0.0733599566403401, 4',
#  'Texas Tech, 0.07914430048881974, 5',
#  'Texas Tech, 0.059818649465860976, 6',
#  'Texas Tech, 0.05514543682756625, 7',
#  'BYU, 0.05819637884043169, 1',
#  'BYU, 0.06967657068477724, 2',
#  'BYU, 0.07212910650829751, 3',
#  'BYU, 0.06564023732423128, 4',
#  'BYU, 0.06773320482447213, 5',
#  'BYU, 0.06646103641478686, 6',
#  'BYU, 0.05964776782255032, 7',
#  'USC, 0.06295968027633608, 1',
#  'USC, 0.08071779401333093, 2',
#  'USC, 0.09058488032777305, 3',
#  'USC, 0.08176962830716225, 4',
#  'USC, 0.0842707984212823, 5',
#  'USC, 0.08139115600443589, 6',
#  'USC, 0.06628087689390348, 7',
#  'San Diego St., 0.07398976837399587, 1',
#  'San Diego St., 0.10122998704738023, 2',
#  'San Diego St., 0.09556512461243703, 3',
#  'San Diego St., 0.08095326460123407, 4',
#  'San Diego St., 0.09249235591296547, 5',
#  'San Diego St., 0.07212711925934312, 6',
#  'San Diego St., 0.06508438907282911, 7',
#  'Florida, 0.10000849954253707, 1',
#  'Florida, 0.11934752489302801, 2',
#  'Florida, 0.09466918105520059, 3',
#  'Florida, 0.07581666911067014, 4',
#  'Florida, 0.08697109359145629, 5',
#  'Florida, 0.06033704977494519, 6',
#  'Florida, 0.05769025152368972, 7',
#  'Connecticut, 0.06467898775370047, 1',
#  'Connecticut, 0.08551388458602512, 2',
#  'Connecticut, 0.0815296112099826, 3',
#  'Connecticut, 0.06957713191778897, 4',
#  'Connecticut, 0.08012804590522925, 5',
#  'Connecticut, 0.062059103676990246, 6',
#  'Connecticut, 0.05907705095877541, 7',
#  'Clemson, 0.05191774170030059, 1',
#  'Clemson, 0.05373690422074132, 2',
#  'Clemson, 0.05056354277252238, 3',
#  'Clemson, 0.04468893923251779, 4',
#  'Clemson, 0.049356592572563224, 5',
#  'Clemson, 0.04334082206145543, 6',
#  'Clemson, 0.04143636899825424, 7',
#  'Oregon, 0.06030479378264502, 1',
#  'Oregon, 0.06590947137377082, 2',
#  'Oregon, 0.06604875617057519, 3',
#  'Oregon, 0.05856410053428661, 4',
#  'Oregon, 0.06058276988464278, 5',
#  'Oregon, 0.05653131817707303, 6',
#  'Oregon, 0.05386785383645829, 7',
#  'Oklahoma, 0.05929216536584536, 1',
#  'Oklahoma, 0.062424756656459565, 2',
#  'Oklahoma, 0.06208052562146618, 3',
#  'Oklahoma, 0.053941315608778906, 4',
#  'Oklahoma, 0.05689171716757406, 5',
#  'Oklahoma, 0.054774218300923085, 6',
#  'Oklahoma, 0.048823816401336664, 7',
#  'North Carolina, 0.056475636785575184, 1',
#  'North Carolina, 0.061523366976133795, 2',
#  'North Carolina, 0.061668496807899174, 3',
#  'North Carolina, 0.05387360447374386, 4',
#  'North Carolina, 0.05623195849278205, 5',
#  'North Carolina, 0.05019332077593748, 6',
#  'North Carolina, 0.04627249056330219, 7',
#  'LSU, 0.062359769708393395, 1',
#  'LSU, 0.07335344255745886, 2',
#  'LSU, 0.0773868076552154, 3',
#  'LSU, 0.07230989305547147, 4',
#  'LSU, 0.06984809839267227, 5',
#  'LSU, 0.06487863857415156, 6',
#  'LSU, 0.062385817034939034, 7',
#  'Loyola Chicago, 0.043273711444737586, 1',
#  'Loyola Chicago, 0.04713172883247604, 2',
#  'Loyola Chicago, 0.04795405749605225, 3',
#  'Loyola Chicago, 0.046146149253827165, 4',
#  'Loyola Chicago, 0.04721190744599525, 5',
#  'Loyola Chicago, 0.04818081490285714, 6',
#  'Loyola Chicago, 0.044590692738479334, 7',
#  'St. Bonaventure, 0.06380338639731073, 1',
#  'St. Bonaventure, 0.07839825050926709, 2',
#  'St. Bonaventure, 0.07752604884016412, 3',
#  'St. Bonaventure, 0.06498482944015992, 4',
#  'St. Bonaventure, 0.0775339279745332, 5',
#  'St. Bonaventure, 0.06364560504312085, 6',
#  'St. Bonaventure, 0.05847398421158253, 7',
#  'Missouri, 0.11276637417087296, 1',
#  'Missouri, 0.1192648854724424, 2',
#  'Missouri, 0.09004419941666084, 3',
#  'Missouri, 0.0744029093463818, 4',
#  'Missouri, 0.07492911731379225, 5',
#  'Missouri, 0.059977029544658576, 6',
#  'Missouri, 0.05362851786340505, 7',
#  'Wisconsin, 0.0509161234649568, 1',
#  'Wisconsin, 0.05591886072469285, 2',
#  'Wisconsin, 0.05480020763644802, 3',
#  'Wisconsin, 0.04899433793354248, 4',
#  'Wisconsin, 0.05363688905043739, 5',
#  'Wisconsin, 0.04983335689953806, 6',
#  'Wisconsin, 0.046149002960078934, 7',
#  'Georgia Tech, 0.0582467567879544, 1',
#  'Georgia Tech, 0.06255359417037852, 2',
#  'Georgia Tech, 0.06116085871511301, 3',
#  'Georgia Tech, 0.055496342613625224, 4',
#  'Georgia Tech, 0.05608452220297979, 5',
#  'Georgia Tech, 0.05284469794878141, 6',
#  'Georgia Tech, 0.050520702495292225, 7',
#  'Rutgers, 0.06651724388784244, 1',
#  'Rutgers, 0.06939055579893802, 2',
#  'Rutgers, 0.06131264964293042, 3',
#  'Rutgers, 0.05283900025794848, 4',
#  'Rutgers, 0.057703484812570205, 5',
#  'Rutgers, 0.04953404785302367, 6',
#  'Rutgers, 0.04567096969036509, 7',
#  'Virginia Tech, 0.0984686183801139, 1',
#  'Virginia Tech, 0.10118714520310218, 2',
#  'Virginia Tech, 0.08624898744438318, 3',
#  'Virginia Tech, 0.06897147007497298, 4',
#  'Virginia Tech, 0.07250286699583335, 5',
#  'Virginia Tech, 0.062263811817128534, 6',
#  'Virginia Tech, 0.053991485909625374, 7',
#  'Maryland, 0.05756573047511091, 1',
#  'Maryland, 0.05836864041910671, 2',
#  'Maryland, 0.056270778561644086, 3',
#  'Maryland, 0.05092284345244178, 4',
#  'Maryland, 0.05236568600731282, 5',
#  'Maryland, 0.05097905969842484, 6',
#  'Maryland, 0.045259506944148487, 7',
#  'VCU, 0.06815475059985665, 1',
#  'VCU, 0.06861334244224004, 2',
#  'VCU, 0.05895034274096876, 3',
#  'VCU, 0.0519467213722282, 4',
#  'VCU, 0.05773876347683204, 5',
#  'VCU, 0.045605333619230255, 6',
#  'VCU, 0.043543678691797295, 7',
#  'Michigan St., 0.07546369366995426, 1',
#  'Michigan St., 0.07023727717162619, 2',
#  'Michigan St., 0.05935499762179809, 3',
#  'Michigan St., 0.05007886916130605, 4',
#  'Michigan St., 0.054047772786382856, 5',
#  'Michigan St., 0.0450501634964387, 6',
#  'Michigan St., 0.04130746686807755, 7',
#  'Wichita St., 0.0863601288157976, 1',
#  'Wichita St., 0.07762976818151006, 2',
#  'Wichita St., 0.06725515975247079, 3',
#  'Wichita St., 0.05623758857082028, 4',
#  'Wichita St., 0.06185742993370704, 5',
#  'Wichita St., 0.049348692801499665, 6',
#  'Wichita St., 0.04529547952073926, 7',
#  'Syracuse, 0.061179966077596015, 1',
#  'Syracuse, 0.06471094426496334, 2',
#  'Syracuse, 0.06337885226541569, 3',
#  'Syracuse, 0.05507694642479553, 4',
#  'Syracuse, 0.05933529168734443, 5',
#  'Syracuse, 0.052618267593345286, 6',
#  'Syracuse, 0.04993335280773038, 7',
#  'UCLA, 0.08106345453800508, 1',
#  'UCLA, 0.08380527792465364, 2',
#  'UCLA, 0.08011553119618615, 3',
#  'UCLA, 0.06563602171781385, 4',
#  'UCLA, 0.0666049227202918, 5',
#  'UCLA, 0.06141760865207589, 6',
#  'UCLA, 0.05394970465440157, 7',
#  'Utah St., 0.05199057981908757, 1',
#  'Utah St., 0.05365467944750239, 2',
#  'Utah St., 0.05188066646465607, 3',
#  'Utah St., 0.04572477155792783, 4',
#  'Utah St., 0.04915932080933839, 5',
#  'Utah St., 0.045100239876996004, 6',
#  'Utah St., 0.04102686855475565, 7',
#  'Drake, 0.05837840469915686, 1',
#  'Drake, 0.05994337048873332, 2',
#  'Drake, 0.05758865571961981, 3',
#  'Drake, 0.051595628014470846, 4',
#  'Drake, 0.052527501813045684, 5',
#  'Drake, 0.04972995453480938, 6',
#  'Drake, 0.046575714610264364, 7',
#  'Georgetown, 0.06530767997724012, 1',
#  'Georgetown, 0.06468434248660988, 2',
#  'Georgetown, 0.06196709943600812, 3',
#  'Georgetown, 0.051591697492809944, 4',
#  'Georgetown, 0.05732143657993639, 5',
#  'Georgetown, 0.048529770921308904, 6',
#  'Georgetown, 0.044898952618291244, 7',
#  'Oregon St., 0.08947963855208035, 1',
#  'Oregon St., 0.06839100768067581, 2',
#  'Oregon St., 0.05617239447442845, 3',
#  'Oregon St., 0.047622745156428926, 4',
#  'Oregon St., 0.05032790785594325, 5',
#  'Oregon St., 0.041461968837226616, 6',
#  'Oregon St., 0.039020806723767454, 7',
#  'UC Santa Barbara, 0.09455624154420128, 1',
#  'UC Santa Barbara, 0.083290750580502, 2',
#  'UC Santa Barbara, 0.07212015296789293, 3',
#  'UC Santa Barbara, 0.0607971773500158, 4',
#  'UC Santa Barbara, 0.061932175077335186, 5',
#  'UC Santa Barbara, 0.05573040771808994, 6',
#  'UC Santa Barbara, 0.04849964591524635, 7',
#  'Winthrop, 0.07236625281443794, 1',
#  'Winthrop, 0.06389895681004709, 2',
#  'Winthrop, 0.056472138146540826, 3',
#  'Winthrop, 0.04944213097992917, 4',
#  'Winthrop, 0.04973952200410211, 5',
#  'Winthrop, 0.043300335217958806, 6',
#  'Winthrop, 0.04044914791346162, 7',
#  'Ohio, 0.06783775219647555, 1',
#  'Ohio, 0.06285010491407857, 2',
#  'Ohio, 0.05857333569212333, 3',
#  'Ohio, 0.052026486776059686, 4',
#  'Ohio, 0.05131491300362083, 5',
#  'Ohio, 0.04777489633502765, 6',
#  'Ohio, 0.04483930236863075, 7',
#  'North Texas, 0.06247445482173754, 1',
#  'North Texas, 0.058385391527500954, 2',
#  'North Texas, 0.052034323064211505, 3',
#  'North Texas, 0.045719620328692215, 4',
#  'North Texas, 0.05007539133531541, 5',
#  'North Texas, 0.04279684222229762, 6',
#  'North Texas, 0.04024072989050978, 7',
#  'UNC Greensboro, 0.053297359381408, 1',
#  'UNC Greensboro, 0.04748128467388282, 2',
#  'UNC Greensboro, 0.042107391669868925, 3',
#  'UNC Greensboro, 0.0371299316057534, 4',
#  'UNC Greensboro, 0.03921435567883681, 5',
#  'UNC Greensboro, 0.034905008752051325, 6',
#  'UNC Greensboro, 0.032815226574060004, 7',
#  'Liberty, 0.04810521194928981, 1',
#  'Liberty, 0.045800874979497856, 2',
#  'Liberty, 0.0434229913528358, 3',
#  'Liberty, 0.04031683127252549, 4',
#  'Liberty, 0.040722687490968905, 5',
#  'Liberty, 0.039604173245564304, 6',
#  'Liberty, 0.03696112836210208, 7',
#  'Colgate, 0.052112897920252886, 1',
#  'Colgate, 0.05231206304407315, 2',
#  'Colgate, 0.051539377928505756, 3',
#  'Colgate, 0.04830073199655107, 4',
#  'Colgate, 0.04847772791516618, 5',
#  'Colgate, 0.04684161173371794, 6',
#  'Colgate, 0.04389173096604763, 7',
#  'Eastern Washington, 0.06321056196751136, 1',
#  'Eastern Washington, 0.05407896613699554, 2',
#  'Eastern Washington, 0.049491916720957894, 3',
#  'Eastern Washington, 0.04405073333061528, 4',
#  'Eastern Washington, 0.04457743464715441, 5',
#  'Eastern Washington, 0.04177600536455037, 6',
#  'Eastern Washington, 0.03810354101667993, 7',
#  'Abilene Christian, 0.059497701716163844, 1',
#  'Abilene Christian, 0.05310424199506012, 2',
#  'Abilene Christian, 0.04552712261467023, 3',
#  'Abilene Christian, 0.04115741194539296, 4',
#  'Abilene Christian, 0.043944758327602564, 5',
#  'Abilene Christian, 0.03605983362346577, 6',
#  'Abilene Christian, 0.03508603829814144, 7',
#  'Morehead St., 0.05691446508479491, 1',
#  'Morehead St., 0.04858074527873522, 2',
#  'Morehead St., 0.04463886550459361, 3',
#  'Morehead St., 0.03978620994917903, 4',
#  'Morehead St., 0.04162087774601588, 5',
#  'Morehead St., 0.03732160186082925, 6',
#  'Morehead St., 0.03434409000122495, 7',
#  'Iona, 0.05713370070078808, 1',
#  'Iona, 0.04705832508099842, 2',
#  'Iona, 0.04042498398805638, 3',
#  'Iona, 0.036559516837828036, 4',
#  'Iona, 0.037947583188352244, 5',
#  'Iona, 0.032310068335859234, 6',
#  'Iona, 0.030758575893233123, 7',
#  'Oral Roberts, 0.05338431100807657, 1',
#  'Oral Roberts, 0.043758276611827907, 2',
#  'Oral Roberts, 0.03960185786891405, 3',
#  'Oral Roberts, 0.03559995189482993, 4',
#  'Oral Roberts, 0.03649672233970155, 5',
#  'Oral Roberts, 0.03291952582840516, 6',
#  'Oral Roberts, 0.03141197906990963, 7',
#  'Grand Canyon, 0.06525037790385783, 1',
#  'Grand Canyon, 0.05709868206791982, 2',
#  'Grand Canyon, 0.05096915365116623, 3',
#  'Grand Canyon, 0.04530074543202203, 4',
#  'Grand Canyon, 0.04664466811108731, 5',
#  'Grand Canyon, 0.04255398808842519, 6',
#  'Grand Canyon, 0.0379771182215793, 7',
#  'Cleveland St., 0.0691235808569369, 1',
#  'Cleveland St., 0.052282457255253934, 2',
#  'Cleveland St., 0.04409045647488846, 3',
#  'Cleveland St., 0.038757187110664955, 4',
#  'Cleveland St., 0.040678309367909296, 5',
#  'Cleveland St., 0.034632274191802516, 6',
#  'Cleveland St., 0.03274610860790524, 7',
#  'Drexel, 0.057993807868968204, 1',
#  'Drexel, 0.04921937569202552, 2',
#  'Drexel, 0.045544999807027024, 3',
#  'Drexel, 0.0405329994208237, 4',
#  'Drexel, 0.041234139626738574, 5',
#  'Drexel, 0.03842995734373917, 6',
#  'Drexel, 0.0356494888491898, 7',
#  "Mount St. Mary's, 0.04406835579866511, 1",
#  "Mount St. Mary's, 0.0374930530839906, 2",
#  "Mount St. Mary's, 0.0344024628131001, 3",
#  "Mount St. Mary's, 0.030913390391580368, 4",
#  "Mount St. Mary's, 0.03261663767523857, 5",
#  "Mount St. Mary's, 0.029701670807037533, 6",
#  "Mount St. Mary's, 0.027637348255378807, 7",
#  'Hartford, 0.047455580767824766, 1',
#  'Hartford, 0.040134151120827855, 2',
#  'Hartford, 0.036499602798674105, 3',
#  'Hartford, 0.032824069809932556, 4',
#  'Hartford, 0.03458588208571305, 5',
#  'Hartford, 0.031189018761896767, 6',
#  'Hartford, 0.029421064321087292, 7',
#  'Norfolk St., 0.06089026144319381, 1',
#  'Norfolk St., 0.04482923973612868, 2',
#  'Norfolk St., 0.03824727334014206, 3',
#  'Norfolk St., 0.034231246663618826, 4',
#  'Norfolk St., 0.035535507327894456, 5',
#  'Norfolk St., 0.03046157112600584, 6',
#  'Norfolk St., 0.02885109017080804, 7',
#  'Texas Southern, 0.05480786187769569, 1',
#  'Texas Southern, 0.04257487975593526, 2',
#  'Texas Southern, 0.03747433191330424, 3',
#  'Texas Southern, 0.03367638810476757, 4',
#  'Texas Southern, 0.03428437586946988, 5',
#  'Texas Southern, 0.030840688346889102, 6',
#  'Texas Southern, 0.028482235028929742, 7',
#  'Appalachian St., 0.049067339684966085, 1',
#  'Appalachian St., 0.0391183627171194, 2',
#  'Appalachian St., 0.03547805258427331, 3',
#  'Appalachian St., 0.031629514299935754, 4',
#  'Appalachian St., 0.032959610313117726, 5',
#  'Appalachian St., 0.029807928416070217, 6',
#  'Appalachian St., 0.027933800575115846, 7']

# %% [markdown]
# ### Expanded for comparison to all the s16 teams

# %%
s16_teams_indexed = s16_teams.reset_index()

# %%
# checking the teams most correlated similarity to a team historically

def full_similarity_all(df1, df2):
    final_results = []
    
    for x in df1.TEAM:
        current = []
        max_similarity = 0
        
        for y in df2.index:
            similarity = 1/(spatial.distance.cosine(df1[df1.TEAM == x].drop(columns = ['TEAM', 'SEED', 'BARTHAG']), 
                                         df2[df2.index == y].drop(columns = ['index', 'TEAM', 'SEED', 'POSTSEASON', 'BARTHAG', 'YEAR'])))
            
            if similarity > max_similarity:
                max_similarity = similarity
                current_team = x
                current_postseason_rank = df2[df2.index == y]['POSTSEASON'].unique()[0]
                current_compared_team = df2[df2.index == y]['TEAM'].unique()[0]
        current.append(current_team)
        current.append(max_similarity)
        current.append(current_compared_team)
        current.append(current_postseason_rank)
        final_results.append(current)
        
        
    return final_results

# %%
Team_comparison = pd.DataFrame(full_similarity_all(cbb21, s16_teams_indexed), 
                              columns = ['Active_Team', 'Similarity_Score', 
                                         'Best_Comparison_Team', 'Postseason_Finish'])

# %%
Teams_by_avg_postseason.to_csv('Teams_by_avg_postseason.csv')
Team_comparison.to_csv(Team_comparison.csv)
